# %% [markdown]
# <a href="https://colab.research.google.com/github/Harinihari5771/Algorithm/blob/main/lin_search(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

def linear_search(arr, x):
  for i in range(len(arr)):
    if arr[i] == x:
      return i
  return -1
n= np.arange(100, 1000, 100)  # Arrays from size 100 to 1000, step 100
execution_times = []

for size in n:
  arr = np.arange(size)
  x = np.random.randint(0, size)
  start_time = time.time()
  linear_search(arr, x)
  end_time = time.time()
  execution_times.append(end_time - start_time)
plt.plot(n, execution_times)
plt.xlabel("Array Size (n)")
plt.ylabel("Execution Time (seconds)")
plt.title("Time Complexity of Linear Search")
plt.show()
